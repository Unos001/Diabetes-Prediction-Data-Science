# %%
import pandas as pd

columns = [
    "Pregnancies",
    "Glucose",
    "BloodPressure",
    "SkinThickness",
    "Insulin",
    "BMI",
    "DiabetesPedigreeFunction",
    "Age",
    "Outcome"
]

# Load dataset
df = pd.read_csv("../datasets/diabetes.csv", names=columns)

#check
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 769 entries, 0 to 768
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               769 non-null    str
#  1   Glucose                   769 non-null    str
#  2   BloodPressure             769 non-null    str
#  3   SkinThickness             769 non-null    str
#  4   Insulin                   769 non-null    str
#  5   BMI                       769 non-null    str
#  6   DiabetesPedigreeFunction  769 non-null    str
#  7   Age                       769 non-null    str
#  8   Outcome                   769 non-null    str
# dtypes: str(9)
# memory usage: 54.2 KB
#        Pregnancies Glucose BloodPressure SkinThickness Insulin  BMI  \
# count          769     769           769           769     769  769
# unique          18     137            48            52     187  249
# ...

# %%
zero_columns = ["Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI"]

for col in zero_columns:
    print(col, "zero values:", (df[col] == 0).sum())

#checking zero values..
# Out:
# Glucose zero values: 0
# BloodPressure zero values: 0
# SkinThickness zero values: 0
# Insulin zero values: 0
# BMI zero values: 0

# %%
zero_columns = ["Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI"]

for col in zero_columns:
    print(col, "zero count:", (df[col] == 0).sum())
# Out:
# Glucose zero count: 0
# BloodPressure zero count: 0
# SkinThickness zero count: 0
# Insulin zero count: 0
# BMI zero count: 0

# %%
df.shape
df.columns

df = pd.read_csv("../datasets/diabetes.csv")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Feature Correlation Heatmap")
plt.show()
#creating heatmap

# %%
df["Outcome"].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x="Outcome", data=df)
plt.title("Diabetes Outcome Distribution")
plt.show()

# %%
important_cols = ["Glucose", "BMI", "Age", "Pregnancies"]
#we'll check the distribution of these important features

for col in important_cols:
    plt.figure()
    sns.histplot(df[col], kde=True)
    plt.title(f"Distribution of {col}")
    plt.show()

# %%
#outcomes based on important features
sns.boxplot(x="Outcome", y="Glucose", data=df)
plt.title("Glucose vs Diabetes")
plt.show()
